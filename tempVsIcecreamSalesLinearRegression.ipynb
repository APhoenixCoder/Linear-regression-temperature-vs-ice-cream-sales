# %% [markdown]
# When manually tested on desmos for a few points:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Temperature  Ice Cream Profits
# 0           39              13.17
# 1           40              11.88
# 2           41              18.82
# 3           42              18.65
# 4           43              17.02

# %%
temp=df['Temperature']
icp=df['Ice Cream Profits']


plt.scatter(temp,icp,color='pink')
plt.xlabel('Temperature')
plt.ylabel('Ice Cream Profits')
plt.show()

# %% [markdown]
# In conclusion linear regression is present and should work here as we can see an upward trend

# %% [markdown]
# Equation of a line:
# y=mx+c
# m is the gradient
# c is the y intercept (bias)
# Assuming m is 2 and c is 5
# y=2x+5
# When x is 39, y would be 83(but its not)
